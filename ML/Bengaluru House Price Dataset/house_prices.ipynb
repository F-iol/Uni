# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bengaluru_house_prices.csv')

# %%
train_df = df.copy()

# %%
from sklearn.model_selection import train_test_split


train_df ,test_df =train_test_split(df,test_size=.2,random_state=69)
train_df ,val_df =train_test_split(df,test_size=.25,random_state=69)

# %%
train_df.describe()
# Out:
#               bath      balcony        price
# count  9945.000000  9533.000000  9990.000000
# mean      2.693313     1.573272   111.359511
# std       1.363846     0.811690   142.934786
# min       1.000000     0.000000     8.000000
# 25%       2.000000     1.000000    50.000000
# 50%       2.000000     2.000000    72.000000
# 75%       3.000000     2.000000   120.000000
# max      40.000000     3.000000  3600.000000

# %%
INR_per_lakh = 100000
USD_per_INR = 1/83

# %%
def usd_price(df):
    df['price_usd'] = df['price'] *INR_per_lakh * USD_per_INR

# %%
usd_price(train_df)
usd_price(val_df)
usd_price(test_df)

# %%
def extract_bedrooms(df):
    df['bedroom'] = df['size'].str.extract(r'(\d+)').astype(float)

# %%
extract_bedrooms(train_df)
extract_bedrooms(val_df)
extract_bedrooms(test_df)

# %%
train_df
# Out:
#                   area_type   availability              location       size  \
# 9496   Super built-up  Area         18-Apr          Banashankari      2 BHK
# 12149  Super built-up  Area  Ready To Move           Mallasandra      3 BHK
# 9162   Super built-up  Area  Ready To Move          Dairy Circle      2 BHK
# 8871   Super built-up  Area  Ready To Move        Jalahalli East      1 BHK
# 8290   Super built-up  Area  Ready To Move                Hennur      2 BHK
# ...                     ...            ...                   ...        ...
# 8631   Super built-up  Area         18-Jun              Abbigere      3 BHK
# 9818   Super built-up  Area  Ready To Move            Seegehalli      3 BHK
# 10859  Super built-up  Area  Ready To Move        Ambedkar Nagar      3 BHK
# 4041   Super built-up  Area  Ready To Move  Poorna Pragna Layout      3 BHK
# 7371             Plot  Area  Ready To Move           Brookefield  5 Bedroom
#
#        society total_sqft  bath  balcony   price      price_usd  bedroom
# 9496   Bregae        1430   2.0      2.0   87.80  105783.132530      2.0
# 12149  ShnyeSy       1524   2.0      3.0   72.00   86746.987952      3.0
# 9162   Soeurri       1541   2.0      1.0  181.00  218072.289157      2.0
# 8871   ShshaSa  750 - 800   1.0      0.0   34.10   41084.337349      1.0
# 8290       NaN       1100   2.0      1.0   44.55   53674.698795      2.0
# ...        ...        ...   ...      ...     ...            ...      ...
# 8631   DSestma       1326   2.0      1.0   35.00   42168.674699      3.0
# 9818   Niowshi       1683   3.0      3.0   80.00   96385.542169      3.0
# 10859  SoechHa       1935   4.0      2.0  125.00  150602.409639      3.0
# 4041       NaN       1270   2.0      2.0   50.79   61192.771084      3.0
# 7371   Goodsrb       1950   6.0      3.0  175.00  210843.373494      5.0
#
# [9990 rows x 11 columns]

# %%
train_df.total_sqft.value_counts()
# Out:
# total_sqft
# 1200            637
# 1100            175
# 1500            147
# 1000            137
# 2400            137
#                ...
# 1462              1
# 1932.47           1
# 7514              1
# 456               1
# 315Sq. Yards      1
# Name: count, Length: 1875, dtype: int64

# %%
def convert_sqft(row):
    try:
        if '-' in row:
            num = row.split('-')
            if len(num) == 2:
                return (float(num[0]) +float(num[1])) / 2
        return float(row)
    except:
        return np.nan

# %%
train_df['sqft'] = train_df['total_sqft'].apply(convert_sqft)
test_df['sqft']= test_df['total_sqft'].apply(convert_sqft)
val_df['sqft']=val_df['total_sqft'].apply(convert_sqft)

# %%
train_df
# Out:
#                   area_type   availability              location       size  \
# 9496   Super built-up  Area         18-Apr          Banashankari      2 BHK
# 12149  Super built-up  Area  Ready To Move           Mallasandra      3 BHK
# 9162   Super built-up  Area  Ready To Move          Dairy Circle      2 BHK
# 8871   Super built-up  Area  Ready To Move        Jalahalli East      1 BHK
# 8290   Super built-up  Area  Ready To Move                Hennur      2 BHK
# ...                     ...            ...                   ...        ...
# 8631   Super built-up  Area         18-Jun              Abbigere      3 BHK
# 9818   Super built-up  Area  Ready To Move            Seegehalli      3 BHK
# 10859  Super built-up  Area  Ready To Move        Ambedkar Nagar      3 BHK
# 4041   Super built-up  Area  Ready To Move  Poorna Pragna Layout      3 BHK
# 7371             Plot  Area  Ready To Move           Brookefield  5 Bedroom
#
#        society total_sqft  bath  balcony   price      price_usd  bedroom  \
# 9496   Bregae        1430   2.0      2.0   87.80  105783.132530      2.0
# 12149  ShnyeSy       1524   2.0      3.0   72.00   86746.987952      3.0
# 9162   Soeurri       1541   2.0      1.0  181.00  218072.289157      2.0
# 8871   ShshaSa  750 - 800   1.0      0.0   34.10   41084.337349      1.0
# 8290       NaN       1100   2.0      1.0   44.55   53674.698795      2.0
# ...        ...        ...   ...      ...     ...            ...      ...
# 8631   DSestma       1326   2.0      1.0   35.00   42168.674699      3.0
# 9818   Niowshi       1683   3.0      3.0   80.00   96385.542169      3.0
# 10859  SoechHa       1935   4.0      2.0  125.00  150602.409639      3.0
# 4041       NaN       1270   2.0      2.0   50.79   61192.771084      3.0
# 7371   Goodsrb       1950   6.0      3.0  175.00  210843.373494      5.0
#
#          sqft
# 9496   1430.0
# 12149  1524.0
# 9162   1541.0
# 8871    775.0
# 8290   1100.0
# ...       ...
# 8631   1326.0
# 9818   1683.0
# 10859  1935.0
# 4041   1270.0
# 7371   1950.0
#
# [9990 rows x 12 columns]

# %%
train_df=train_df.dropna(subset=['sqft','bedroom','location'])
val_df = val_df.dropna(subset=['sqft','bedroom','location'])
test_df = test_df.dropna(subset=['sqft','bedroom','location'])

# %%
train_df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               0
# society         4120
# total_sqft         0
# bath              38
# balcony          447
# price              0
# price_usd          0
# bedroom            0
# sqft               0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
bath_imputer = SimpleImputer(strategy='median')

# %%
bath_imputer.fit(train_df[['bath']])
# Out:
# SimpleImputer(strategy='median')

# %%
train_df['bath']=bath_imputer.transform(train_df[['bath']])
test_df['bath']=bath_imputer.transform(test_df[['bath']])
val_df['bath']=bath_imputer.transform(val_df[['bath']])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\3947663790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['bath']=bath_imputer.transform(train_df[['bath']])

# %%
train_df['balcony']=train_df['balcony'].fillna(0)
val_df['balcony']=val_df['balcony'].fillna(0)
test_df['balcony']=test_df['balcony'].fillna(0)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\1358428725.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['balcony']=train_df['balcony'].fillna(0)

# %%
def sqft_per_bedroom(df):
    df = df[df["sqft"] / df["bedroom"] >= 200]

# %%
sqft_per_bedroom(train_df)
sqft_per_bedroom(val_df)
sqft_per_bedroom(test_df)

# %%
def listing_frequecny(df):
    location_count = df['location'].value_counts()
    df['location_listing_frequency'] = df['location'].map(location_count)

# %%
listing_frequecny(train_df)
listing_frequecny(val_df)
listing_frequecny(test_df)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\3684675342.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location_listing_frequency'] = df['location'].map(location_count)

# %%
def price_per_sqft(df):
    df['price_per_sqft'] = df.groupby('location')['price'].transform('mean')

# %%
price_per_sqft(train_df)
price_per_sqft(val_df)
price_per_sqft(test_df)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\187354108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = df.groupby('location')['price'].transform('mean')

# %%
train_df
# Out:
#                   area_type   availability              location       size  \
# 9496   Super built-up  Area         18-Apr          Banashankari      2 BHK
# 12149  Super built-up  Area  Ready To Move           Mallasandra      3 BHK
# 9162   Super built-up  Area  Ready To Move          Dairy Circle      2 BHK
# 8871   Super built-up  Area  Ready To Move        Jalahalli East      1 BHK
# 8290   Super built-up  Area  Ready To Move                Hennur      2 BHK
# ...                     ...            ...                   ...        ...
# 8631   Super built-up  Area         18-Jun              Abbigere      3 BHK
# 9818   Super built-up  Area  Ready To Move            Seegehalli      3 BHK
# 10859  Super built-up  Area  Ready To Move        Ambedkar Nagar      3 BHK
# 4041   Super built-up  Area  Ready To Move  Poorna Pragna Layout      3 BHK
# 7371             Plot  Area  Ready To Move           Brookefield  5 Bedroom
#
#        society total_sqft  bath  balcony   price      price_usd  bedroom  \
# 9496   Bregae        1430   2.0      2.0   87.80  105783.132530      2.0
# 12149  ShnyeSy       1524   2.0      3.0   72.00   86746.987952      3.0
# 9162   Soeurri       1541   2.0      1.0  181.00  218072.289157      2.0
# 8871   ShshaSa  750 - 800   1.0      0.0   34.10   41084.337349      1.0
# 8290       NaN       1100   2.0      1.0   44.55   53674.698795      2.0
# ...        ...        ...   ...      ...     ...            ...      ...
# 8631   DSestma       1326   2.0      1.0   35.00   42168.674699      3.0
# 9818   Niowshi       1683   3.0      3.0   80.00   96385.542169      3.0
# 10859  SoechHa       1935   4.0      2.0  125.00  150602.409639      3.0
# 4041       NaN       1270   2.0      2.0   50.79   61192.771084      3.0
# 7371   Goodsrb       1950   6.0      3.0  175.00  210843.373494      5.0
#
#          sqft  location_listing_frequency  price_per_sqft
# 9496   1430.0                          47      102.011064
# 12149  1524.0                          12       67.608333
# 9162   1541.0                           7      314.571429
# 8871    775.0                          11       56.007273
# 8290   1100.0                          47       76.455851
# ...       ...                         ...             ...
# 8631   1326.0                          16       58.525625
# 9818   1683.0                          22      130.842727
# 10859  1935.0                          25      188.280000
# 4041   1270.0                          16       76.735625
# 7371   1950.0                          35      113.371429
#
# [9944 rows x 14 columns]

# %%
train_df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price', 'price_usd', 'bedroom',
#        'sqft', 'location_listing_frequency', 'price_per_sqft'],
#       dtype='object')

# %%
input_cols = [ 'bath', 'balcony', 'bedroom','sqft','location_listing_frequency','price_per_sqft']
target_col = 'price_usd'

# %%
top_locations = train_df.location.value_counts().nlargest(25).index
def loc_end(df):
    df['location_encoded'] = df['location'].where(df['location'].isin(top_locations),'Other')

# %%
loc_end(train_df)
loc_end(val_df)
loc_end(test_df)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\1087605830.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['location_encoded'] = df['location'].where(df['location'].isin(top_locations),'Other')

# %%
train_df
# Out:
#                   area_type   availability              location       size  \
# 9496   Super built-up  Area         18-Apr          Banashankari      2 BHK
# 12149  Super built-up  Area  Ready To Move           Mallasandra      3 BHK
# 9162   Super built-up  Area  Ready To Move          Dairy Circle      2 BHK
# 8871   Super built-up  Area  Ready To Move        Jalahalli East      1 BHK
# 8290   Super built-up  Area  Ready To Move                Hennur      2 BHK
# ...                     ...            ...                   ...        ...
# 8631   Super built-up  Area         18-Jun              Abbigere      3 BHK
# 9818   Super built-up  Area  Ready To Move            Seegehalli      3 BHK
# 10859  Super built-up  Area  Ready To Move        Ambedkar Nagar      3 BHK
# 4041   Super built-up  Area  Ready To Move  Poorna Pragna Layout      3 BHK
# 7371             Plot  Area  Ready To Move           Brookefield  5 Bedroom
#
#        society total_sqft  bath  balcony   price      price_usd  bedroom  \
# 9496   Bregae        1430   2.0      2.0   87.80  105783.132530      2.0
# 12149  ShnyeSy       1524   2.0      3.0   72.00   86746.987952      3.0
# 9162   Soeurri       1541   2.0      1.0  181.00  218072.289157      2.0
# 8871   ShshaSa  750 - 800   1.0      0.0   34.10   41084.337349      1.0
# 8290       NaN       1100   2.0      1.0   44.55   53674.698795      2.0
# ...        ...        ...   ...      ...     ...            ...      ...
# 8631   DSestma       1326   2.0      1.0   35.00   42168.674699      3.0
# 9818   Niowshi       1683   3.0      3.0   80.00   96385.542169      3.0
# 10859  SoechHa       1935   4.0      2.0  125.00  150602.409639      3.0
# 4041       NaN       1270   2.0      2.0   50.79   61192.771084      3.0
# 7371   Goodsrb       1950   6.0      3.0  175.00  210843.373494      5.0
#
#          sqft  location_listing_frequency  price_per_sqft location_encoded
# 9496   1430.0                          47      102.011064            Other
# 12149  1524.0                          12       67.608333            Other
# 9162   1541.0                           7      314.571429            Other
# 8871    775.0                          11       56.007273            Other
# 8290   1100.0                          47       76.455851            Other
# ...       ...                         ...             ...              ...
# 8631   1326.0                          16       58.525625            Other
# 9818   1683.0                          22      130.842727            Other
# 10859  1935.0                          25      188.280000            Other
# 4041   1270.0                          16       76.735625            Other
# 7371   1950.0                          35      113.371429            Other
#
# [9944 rows x 15 columns]

# %%
cat_cols = ['location_encoded','area_type']

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(handle_unknown='ignore',sparse_output=False)

# %%
encoder.fit(train_df[cat_cols])
# Out:
# OneHotEncoder(handle_unknown='ignore', sparse_output=False)

# %%
encoded_cols = list(encoder.get_feature_names_out(cat_cols))

# %%
train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
val_df[encoded_cols] = encoder.transform(val_df[cat_cols])
test_df[encoded_cols] = encoder.transform(test_df[cat_cols])
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])
# C:\Users\danie\AppData\Local\Temp\ipykernel_25356\744925998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df[encoded_cols] = encoder.transform(train_df[cat_cols])

# %%
train_input = train_df[input_cols + encoded_cols]
val_input = val_df[input_cols + encoded_cols]
test_input = test_df[input_cols + encoded_cols]

train_target = train_df[target_col]
val_target = val_df[target_col]
test_target = test_df[target_col]

# %%
train_input
# Out:
#        bath  balcony  bedroom    sqft  location_listing_frequency  \
# 9496    2.0      2.0      2.0  1430.0                          47
# 12149   2.0      3.0      3.0  1524.0                          12
# 9162    2.0      1.0      2.0  1541.0                           7
# 8871    1.0      0.0      1.0   775.0                          11
# 8290    2.0      1.0      2.0  1100.0                          47
# ...     ...      ...      ...     ...                         ...
# 8631    2.0      1.0      3.0  1326.0                          16
# 9818    3.0      3.0      3.0  1683.0                          22
# 10859   4.0      2.0      3.0  1935.0                          25
# 4041    2.0      2.0      3.0  1270.0                          16
# 7371    6.0      3.0      5.0  1950.0                          35
#
#        price_per_sqft  location_encoded_7th Phase JP Nagar  \
# 9496       102.011064                                  0.0
# 12149       67.608333                                  0.0
# 9162       314.571429                                  0.0
# 8871        56.007273                                  0.0
# 8290        76.455851                                  0.0
# ...               ...                                  ...
# 8631        58.525625                                  0.0
# 9818       130.842727                                  0.0
# 10859      188.280000                                  0.0
# 4041        76.735625                                  0.0
# 7371       113.371429                                  0.0
#
#        location_encoded_Bannerghatta Road  location_encoded_Begur Road  \
# 9496                                  0.0                          0.0
# 12149                                 0.0                          0.0
# 9162                                  0.0                          0.0
# 8871                                  0.0                          0.0
# 8290                                  0.0                          0.0
# ...                                   ...                          ...
# 8631                                  0.0                          0.0
# 9818                                  0.0                          0.0
# 10859                                 0.0                          0.0
# 4041                                  0.0                          0.0
# 7371                                  0.0                          0.0
#
#        location_encoded_Bellandur  ...  location_encoded_Sarjapur  Road  \
# 9496                          0.0  ...                              0.0
# 12149                         0.0  ...                              0.0
# 9162                          0.0  ...                              0.0
# 8871                          0.0  ...                              0.0
# 8290                          0.0  ...                              0.0
# ...                           ...  ...                              ...
# 8631                          0.0  ...                              0.0
# 9818                          0.0  ...                              0.0
# 10859                         0.0  ...                              0.0
# 4041                          0.0  ...                              0.0
# 7371                          0.0  ...                              0.0
#
#        location_encoded_Thanisandra  location_encoded_Uttarahalli  \
# 9496                            0.0                           0.0
# 12149                           0.0                           0.0
# 9162                            0.0                           0.0
# 8871                            0.0                           0.0
# 8290                            0.0                           0.0
# ...                             ...                           ...
# 8631                            0.0                           0.0
# 9818                            0.0                           0.0
# 10859                           0.0                           0.0
# 4041                            0.0                           0.0
# 7371                            0.0                           0.0
#
#        location_encoded_Whitefield  location_encoded_Yelahanka  \
# 9496                           0.0                         0.0
# 12149                          0.0                         0.0
# 9162                           0.0                         0.0
# 8871                           0.0                         0.0
# 8290                           0.0                         0.0
# ...                            ...                         ...
# 8631                           0.0                         0.0
# 9818                           0.0                         0.0
# 10859                          0.0                         0.0
# 4041                           0.0                         0.0
# 7371                           0.0                         0.0
#
#        location_encoded_Yeshwanthpur  area_type_Built-up  Area  \
# 9496                             0.0                       0.0
# 12149                            0.0                       0.0
# 9162                             0.0                       0.0
# 8871                             0.0                       0.0
# 8290                             0.0                       0.0
# ...                              ...                       ...
# 8631                             0.0                       0.0
# 9818                             0.0                       0.0
# 10859                            0.0                       0.0
# 4041                             0.0                       0.0
# 7371                             0.0                       0.0
#
#        area_type_Carpet  Area  area_type_Plot  Area  \
# 9496                      0.0                   0.0
# 12149                     0.0                   0.0
# 9162                      0.0                   0.0
# 8871                      0.0                   0.0
# 8290                      0.0                   0.0
# ...                       ...                   ...
# 8631                      0.0                   0.0
# 9818                      0.0                   0.0
# 10859                     0.0                   0.0
# 4041                      0.0                   0.0
# 7371                      0.0                   1.0
#
#        area_type_Super built-up  Area
# 9496                              1.0
# 12149                             1.0
# 9162                              1.0
# 8871                              1.0
# 8290                              1.0
# ...                               ...
# 8631                              1.0
# 9818                              1.0
# 10859                             1.0
# 4041                              1.0
# 7371                              0.0
#
# [9944 rows x 36 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(train_input[input_cols])
# Out:
# StandardScaler()

# %%
x_train = scaler.transform(train_input[input_cols])

# %%
cat_data =train_input[encoded_cols].values

# %%
inputs = np.concatenate((x_train,cat_data),axis=1)

# %%
model =LinearRegression(n_jobs=-1)

# %%
model.fit(inputs,train_target)
# Out:
# LinearRegression(n_jobs=-1)

# %%
model.score(inputs,train_target)
# Out:
# 0.6071806505012081

# %%
model.score(val_input,val_target)
# Out:
# C:\Users\danie\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -398417.91021248605

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_1 = RandomForestRegressor(n_jobs=-1,n_estimators=133,random_state=69,min_samples_leaf=4,max_depth=11,max_features=19)

# %%
model_1.fit(train_input,train_target)
# Out:
# RandomForestRegressor(max_depth=11, max_features=19, min_samples_leaf=4,
#                       n_estimators=133, n_jobs=-1, random_state=69)

# %%
model_1.score(train_input,train_target)
# Out:
# 0.8717477873411451

# %%
model_1.score(val_input,val_target)
# Out:
# 0.8095140979543299

# %%
train_input
# Out:
#        bath  balcony  bedroom    sqft  location_listing_frequency  \
# 9496    2.0      2.0      2.0  1430.0                          47
# 12149   2.0      3.0      3.0  1524.0                          12
# 9162    2.0      1.0      2.0  1541.0                           7
# 8871    1.0      0.0      1.0   775.0                          11
# 8290    2.0      1.0      2.0  1100.0                          47
# ...     ...      ...      ...     ...                         ...
# 8631    2.0      1.0      3.0  1326.0                          16
# 9818    3.0      3.0      3.0  1683.0                          22
# 10859   4.0      2.0      3.0  1935.0                          25
# 4041    2.0      2.0      3.0  1270.0                          16
# 7371    6.0      3.0      5.0  1950.0                          35
#
#        price_per_sqft  location_encoded_7th Phase JP Nagar  \
# 9496       102.011064                                  0.0
# 12149       67.608333                                  0.0
# 9162       314.571429                                  0.0
# 8871        56.007273                                  0.0
# 8290        76.455851                                  0.0
# ...               ...                                  ...
# 8631        58.525625                                  0.0
# 9818       130.842727                                  0.0
# 10859      188.280000                                  0.0
# 4041        76.735625                                  0.0
# 7371       113.371429                                  0.0
#
#        location_encoded_Bannerghatta Road  location_encoded_Begur Road  \
# 9496                                  0.0                          0.0
# 12149                                 0.0                          0.0
# 9162                                  0.0                          0.0
# 8871                                  0.0                          0.0
# 8290                                  0.0                          0.0
# ...                                   ...                          ...
# 8631                                  0.0                          0.0
# 9818                                  0.0                          0.0
# 10859                                 0.0                          0.0
# 4041                                  0.0                          0.0
# 7371                                  0.0                          0.0
#
#        location_encoded_Bellandur  ...  location_encoded_Sarjapur  Road  \
# 9496                          0.0  ...                              0.0
# 12149                         0.0  ...                              0.0
# 9162                          0.0  ...                              0.0
# 8871                          0.0  ...                              0.0
# 8290                          0.0  ...                              0.0
# ...                           ...  ...                              ...
# 8631                          0.0  ...                              0.0
# 9818                          0.0  ...                              0.0
# 10859                         0.0  ...                              0.0
# 4041                          0.0  ...                              0.0
# 7371                          0.0  ...                              0.0
#
#        location_encoded_Thanisandra  location_encoded_Uttarahalli  \
# 9496                            0.0                           0.0
# 12149                           0.0                           0.0
# 9162                            0.0                           0.0
# 8871                            0.0                           0.0
# 8290                            0.0                           0.0
# ...                             ...                           ...
# 8631                            0.0                           0.0
# 9818                            0.0                           0.0
# 10859                           0.0                           0.0
# 4041                            0.0                           0.0
# 7371                            0.0                           0.0
#
#        location_encoded_Whitefield  location_encoded_Yelahanka  \
# 9496                           0.0                         0.0
# 12149                          0.0                         0.0
# 9162                           0.0                         0.0
# 8871                           0.0                         0.0
# 8290                           0.0                         0.0
# ...                            ...                         ...
# 8631                           0.0                         0.0
# 9818                           0.0                         0.0
# 10859                          0.0                         0.0
# 4041                           0.0                         0.0
# 7371                           0.0                         0.0
#
#        location_encoded_Yeshwanthpur  area_type_Built-up  Area  \
# 9496                             0.0                       0.0
# 12149                            0.0                       0.0
# 9162                             0.0                       0.0
# 8871                             0.0                       0.0
# 8290                             0.0                       0.0
# ...                              ...                       ...
# 8631                             0.0                       0.0
# 9818                             0.0                       0.0
# 10859                            0.0                       0.0
# 4041                             0.0                       0.0
# 7371                             0.0                       0.0
#
#        area_type_Carpet  Area  area_type_Plot  Area  \
# 9496                      0.0                   0.0
# 12149                     0.0                   0.0
# 9162                      0.0                   0.0
# 8871                      0.0                   0.0
# 8290                      0.0                   0.0
# ...                       ...                   ...
# 8631                      0.0                   0.0
# 9818                      0.0                   0.0
# 10859                     0.0                   0.0
# 4041                      0.0                   0.0
# 7371                      0.0                   1.0
#
#        area_type_Super built-up  Area
# 9496                              1.0
# 12149                             1.0
# 9162                              1.0
# 8871                              1.0
# 8290                              1.0
# ...                               ...
# 8631                              1.0
# 9818                              1.0
# 10859                             1.0
# 4041                              1.0
# 7371                              0.0
#
# [9944 rows x 36 columns]

# %%
train_input.columns
# Out:
# Index(['bath', 'balcony', 'bedroom', 'sqft', 'location_listing_frequency',
#        'price_per_sqft', 'location_encoded_7th Phase JP Nagar',
#        'location_encoded_Bannerghatta Road', 'location_encoded_Begur Road',
#        'location_encoded_Bellandur', 'location_encoded_Chandapura',
#        'location_encoded_Electronic City',
#        'location_encoded_Electronic City Phase II',
#        'location_encoded_Electronics City Phase 1',
#        'location_encoded_Haralur Road', 'location_encoded_Harlur',
#        'location_encoded_Hebbal', 'location_encoded_Hennur Road',
#        'location_encoded_Hoodi', 'location_encoded_KR Puram',
#        'location_encoded_Kanakpura Road', 'location_encoded_Marathahalli',
#        'location_encoded_Other', 'location_encoded_Raja Rajeshwari Nagar',
#        'location_encoded_Rajaji Nagar', 'location_encoded_Sarjapur',
#        'location_encoded_Sarjapur  Road', 'location_encoded_Thanisandra',
#        'location_encoded_Uttarahalli', 'location_encoded_Whitefield',
#        'location_encoded_Yelahanka', 'location_encoded_Yeshwanthpur',
#        'area_type_Built-up  Area', 'area_type_Carpet  Area',
#        'area_type_Plot  Area', 'area_type_Super built-up  Area'],
#       dtype='object')
